# %% [markdown]
# Name : Jignesh Sunil Tathe

# %% [markdown]
# Branch : CO

# %% [markdown]
# # Assignment 4

# %%
import matplotlib.pyplot as mp
mp.plot([86,87,88,90])
mp.title("Examination Performance")
mp.tight_layout()
mp.grid(True)

# %%
sem = [1,2,3,4]
marks = [86,87,88,90]
mp.plot(sem,marks)
mp.ylabel("Marks")
mp.xlabel("SEM")
mp.title("Performance")
mp.style.use('dark_background')

mp.grid(True)

mp.show()

# %%
sem = [1,2,3,4]
marks = [86,87,88,90]
mp.plot(sem,marks)
mp.ylabel("Marks")
mp.xlabel("SEM")
mp.title("Performance")
mp.style.use('_mpl-gallery')

mp.grid(True)

mp.show()

# %%
sem = [1,2,3,4]
marks = [86,87,88,90]
mp.plot(sem,marks)
mp.ylabel("Marks")
mp.xlabel("SEM")
mp.title("Performance")
mp.style.use('ggplot')

mp.grid(True)

mp.show()

# %%
sem = [1,2,3,4]
marks = [86,87,88,90]
mp.plot(sem,marks)
mp.ylabel("Marks")
mp.xlabel("SEM")
mp.title("Performance")
mp.style.use('bmh')

mp.grid(True)

mp.show()

# %%
sem = [1,2,3,4]
marks = [86,87,88,90]
mp.plot(sem,marks)
mp.ylabel("Marks")
mp.xlabel("SEM")
mp.title("Performance")
mp.style.use('_classic_test_patch')

mp.grid(True)

mp.show()

# %%
sem = [1,2,3,4]
marks = [86,87,88,90]
mp.plot(sem,marks)
mp.ylabel("Marks",color='Black')
mp.xlabel("SEM",color='Black')
mp.title("Performance",color='Black')
mp.style.use('Solarize_Light2')
mp.grid(True)

mp.show()

# %%
sem = [1,2,3,4]
marks = [86,87,88,90]
mp.plot(sem,marks)
mp.ylabel("Marks")
mp.xlabel("SEM")
mp.title("Performance")
mp.style.use('grayscale')

mp.grid(True)

mp.show()

# %%
sem = [1,2,3,4]
marks = [86,87,88,90]
mp.plot(sem,marks)
mp.ylabel("Marks",color='Black')
mp.xlabel("SEM",color='Black')
mp.title("Performance",color='Black')
mp.style.use('seaborn-v0_8')

mp.grid(True)

mp.show()

# %%
sem = [1,2,3,4]
marks = [86,87,88,90]
mp.plot(sem,marks)
mp.ylabel("Marks")
mp.xlabel("SEM")
mp.title("Performance")
mp.style.use('fivethirtyeight')

mp.grid(True)

mp.show()

# %%
sem = [1,2,3,4]
marks = [86,87,88,90]
mp.plot(sem,marks)
mp.ylabel("Marks")
mp.xlabel("SEM")
mp.title("Performance")
mp.style.use('classic')

mp.grid(True)

mp.show()
